# %% [markdown]
# # Comenzando a enter PEP 249

# %% [markdown]
# ### Importar módulo

# %%
import mysql.connector

# %% [markdown]
# Crear el objeto de conexión

# %%
connection = mysql.connector.connect(
    host='lahman.csw1rmup8ri6.us-east-1.rds.amazonaws.com',
    user='python',
    passwd='python',
    db='lahmansbaseballdb'
)

# %% [markdown]
# Opcionalmente, creamos una variable para mayor facilidad de crear la consulta deseada

# %%
query = """SELECT nameFirst, nameLast, weight, year(debut)
           FROM people
           ORDER BY weight DESC
           LIMIT 5"""

# %% [markdown]
# Abrimos la conexión iniciando una instancia de cursor

# %%
cursor = connection.cursor()

# %% [markdown]
# Invocamos la ejecución de la consulta

# %%
cursor.execute(query)

# %% [markdown]
# Invocamos a los métodos que devuelven los resultados

# %%
results = cursor.fetchall()

# %% [markdown]
# Cerramos el cursor

# %%
cursor.close()

# %% [markdown]
# Cerramos la conexión

# %%
connection.close()

# %% [markdown]
# Presentamos los resultados

# %%
print(results)
